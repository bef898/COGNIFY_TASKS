# %% [markdown]
# data reading

# %%
import os
import sys
import pandas as pd
import numpy as np


sys.path.append(os.path.abspath('../data'))
sys.path.append(os.path.abspath('../scripts'))

# %%
data = pd.read_csv(r'C:\Users\befekadum\Documents\intership\cognfiz\COGNIFY_TASKS\data\Dataset  (1).csv')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
from data_proccessing_fun import data_pro

# %%
data_pro = data_pro()

# %%
data_pro.missing_values(data)
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.dropna()
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data_pro.missing_values(data)
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data_pro.get_categorical_columns(data)
# Out:
# ['Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text']

# %%
data_pro.get_numerical_columns(data)
# Out:
# ['Restaurant ID',
#  'Country Code',
#  'Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
data_pro.standardize_column_names(data)
# Out:
#       restaurant_id           restaurant_name  country_code              city  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# Task 1
#
# Top Cuisines
#
# City Analysis
#
# Price Range Distribution
#
# Online Delivery

# %% [markdown]
# Top cuisines

# %%
from task_1_fun import task

# %%
tasks = task()

# %%
tasks.Level_1_Tasks_Tops(data,'cuisines')
# Out:
# (cuisines
#  North Indian    3960
#  Chinese         2735
#  Fast Food       1986
#  Name: count, dtype: int64,
#  cuisines
#  North Indian    41.461627
#  Chinese         28.635745
#  Fast Food       20.793634
#  Name: count, dtype: float64)

# %%
tasks.Level_1_Tasks_Tops(data,'city')
# Out:
# (city
#  New Delhi    5473
#  Gurgaon      1118
#  Noida        1080
#  Name: count, dtype: int64,
#  city
#  New Delhi    57.302900
#  Gurgaon      11.705581
#  Noida        11.307716
#  Name: count, dtype: float64)

# %%
tasks.Level_1_Task3_tops(data,'price_range')
# Out:
# (price_range
#  1    4444
#  2    3113
#  3    1408
#  4     586
#  Name: count, dtype: int64,
#  price_range
#  1    46.529159
#  2    32.593446
#  3    14.741912
#  4     6.135483
#  Name: count, dtype: float64)

# %%
df = pd.DataFrame(data)

# %%
tasks.Level_1_Task4(df)
# Out:
# (has_online_delivery
#  No     74.337766
#  Yes    25.662234
#  Name: count, dtype: float64,
#  np.float64(3.2488372093023257),
#  np.float64(2.465295774647887))

# %% [markdown]
# Level 2 tasks

# %%
from task_2_fun import LevelTwoTasks

# %% [markdown]
#  creating the instance of the class

# %%
LevelTwoTasks = LevelTwoTasks(data)

# %%
LevelTwoTasks.analyze_ratings()
# Out:
# Most Common Rating Range: 0.0
# Average Number of Votes: 156.909747670401
# (np.float64(0.0), np.float64(156.909747670401))

# %%
LevelTwoTasks.cuisine_combinations()
# Out:
# Top 10 Most Common Cuisines:
# cuisines_split
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Mughlai          995
# Italian          764
# Bakery           745
# Continental      736
# Cafe             703
# Desserts         653
# South Indian     636
# Name: count, dtype: int64
#
# Average Ratings for Each Cuisine:
# cuisines_split
# Sunda         4.900000
# B�_rek        4.700000
# Taiwanese     4.650000
# Ramen         4.500000
# Dim Sum       4.466667
# Hawaiian      4.412500
# Bubble Tea    4.400000
# D�_ner        4.400000
# Curry         4.400000
# Kebab         4.380000
# Name: aggregate_rating, dtype: float64
# (cuisines_split
#  North Indian    3960
#  Chinese         2735
#  Fast Food       1986
#  Mughlai          995
#  Italian          764
#  Bakery           745
#  Continental      736
#  Cafe             703
#  Desserts         653
#  South Indian     636
#  Name: count, dtype: int64,
#  cuisines_split
#  Sunda             4.900000
# ...

# %%
LevelTwoTasks.geographic_analysis()
# Out:
#       restaurant_id           restaurant_name  country_code              city  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
LevelTwoTasks.restaurant_chains()
# Out:
# Top Restaurant Chains:
# restaurant_name
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
# Keventers           34
# Pizza Hut           30
# Giani               29
# Baskin Robbins      28
# Barbeque Nation     26
# Name: count, dtype: int64
#
# Ratings for Popular Restaurant Chains:
# restaurant_name
# Talaga Sampireun             4.900
# Silantro Fil-Mex             4.850
# AB's Absolute Barbecues      4.850
# AB's - Absolute Barbecues    4.825
# Naturals Ice Cream           4.800
# Gymkhana                     4.700
# The Cheesecake Factory       4.650
# Garota de Ipanema            4.600
# Dishoom                      4.600
# Chili's                      4.580
# Name: aggregate_rating, dtype: float64
# (restaurant_name
#  Cafe Coffee Day     83
#  Domino's Pizza      79
#  Subway              63
#  Green Chick Chop    51
#  McDonald's          48
#                      ..
#  San Carlo            2
# ...

# %% [markdown]
# level 3 tasks

# %%
from level_three_tasks import LevelThreeTasks

# %%
LevelThreeTasks = LevelThreeTasks(data)

# %%
LevelThreeTasks.analyze_reviews()
# Out:
# Top Positive Words:
#         word  frequency
# 0    average       3737
# 2       good       3179
# 4      rated       2148
# 1  excellent        301
# 3       poor        186
# Average Review Length: 7.020730813527379
# (        word  frequency
#  0    average       3737
#  2       good       3179
#  4      rated       2148
#  1  excellent        301
#  3       poor        186,
#  np.float64(7.020730813527379))

# %%
LevelThreeTasks.votes_analysis()
# Out:
# Restaurant with Highest Votes:
#     restaurant_name  votes  aggregate_rating
# 728            Toit  10934               4.8
#
# Restaurant with Lowest Votes:
#           restaurant_name  votes  aggregate_rating
# 58  Quiosque Chopp Brahma      1               0.0
#
# Correlation between Votes and Ratings: 0.31369058419541146
# (     restaurant_id restaurant_name  country_code       city  \
#  728          51705            Toit             1  Bangalore
#
#                                                 address     locality  \
#  728  298, Namma Metro Pillar 62, 100 Feet Road, Ind...  Indiranagar
#
#             locality_verbose  longitude   latitude                  cuisines  \
#  728  Indiranagar, Bangalore  77.640709  12.979166  Italian, American, Pizza
#
#       ...  has_online_delivery is_delivering_now switch_to_order_menu  \
#  728  ...                   No                No                   No
#
#      price_range aggregate_rating rating_color  rating_text  votes  \
# ...

# %%
LevelThreeTasks.price_range_analysis()
# Out:
# Table Booking Availability by Price Range:
# has_table_booking        No       Yes
# price_range
# 1                  0.999775  0.000225
# 2                  0.923225  0.076775
# 3                  0.542614  0.457386
# 4                  0.532423  0.467577
#
# Online Delivery Availability by Price Range:
# has_online_delivery        No       Yes
# price_range
# 1                    0.842259  0.157741
# 2                    0.586894  0.413106
# 3                    0.708097  0.291903
# 4                    0.909556  0.090444
# (has_table_booking        No       Yes
#  price_range
#  1                  0.999775  0.000225
#  2                  0.923225  0.076775
#  3                  0.542614  0.457386
#  4                  0.532423  0.467577,
#  has_online_delivery        No       Yes
#  price_range
#  1                    0.842259  0.157741
#  2                    0.586894  0.413106
#  3                    0.708097  0.291903
#  4                    0.909556  0.090444)
